# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data.csv', sep=',', header=None)
df.columns = ['population', 'profit']

# %%
df
# Out:
#     population    profit
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# ..         ...       ...
# 92      5.8707   7.20290
# 93      5.3054   1.98690
# 94      8.2934   0.14454
# 95     13.3940   9.05510
# 96      5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
ax = sns.scatterplot(x='population', y='profit', data=df)
ax.set(xlabel='Population of City in 10,000s', ylabel='Profit in $10,000s', title='Scatter plot of training data');

# %%
def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)
  
    # mean of x and y vector
    m_x = np.mean(x)
    m_y = np.mean(y)
  
    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x
#     SS_xy = np.cov(x,y)
#     SS_xx = np.var(x)
  
    # calculating regression coefficients
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x
  
    return (b_0, b_1)

# %%
def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "m",
               marker = "o", s = 30)
  
    # predicted response vector
    y_pred = b[0] + b[1]*x
  
    # plotting the regression line
    plt.plot(x, y_pred, color = "g")
  
    # putting labels
    plt.xlabel('x')
    plt.ylabel('y')
  
    # function to show plot
    plt.show()

# %%
b = estimate_coef(df['population'], df['profit'])
print("Estimated coefficients:\nb_0 = {}  \
      \nb_1 = {}".format(b[0], b[1]))

# plotting regression line
plot_regression_line(df['population'], df['profit'], b)
# Out:
# Estimated coefficients:
# b_0 = -3.895780878311852
# b_1 = 1.1930336441895937
