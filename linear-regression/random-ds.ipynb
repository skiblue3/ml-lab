# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.random.randint(low=0, high=100, size=30)

# %%
y = np.random.randint(low=0, high=100, size=30)

# %%
x.sort()
y.sort()

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
plt.boxplot([x,y], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x253ac3d2440>,
#   <matplotlib.lines.Line2D at 0x253ac3d26e0>,
#   <matplotlib.lines.Line2D at 0x253ac3d36a0>,
#   <matplotlib.lines.Line2D at 0x253ac3d3940>],
#  'caps': [<matplotlib.lines.Line2D at 0x253ac3d2980>,
#   <matplotlib.lines.Line2D at 0x253ac3d2c20>,
#   <matplotlib.lines.Line2D at 0x253ac3d3bb0>,
#   <matplotlib.lines.Line2D at 0x253ac3d3e50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x253ac3d2230>,
#   <matplotlib.lines.Line2D at 0x253ac3d3400>],
#  'medians': [<matplotlib.lines.Line2D at 0x253ac3d2ec0>,
#   <matplotlib.lines.Line2D at 0x253ac408130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x253ac3d3160>,
#   <matplotlib.lines.Line2D at 0x253ac4083d0>],
#  'means': []}

# %%
plt.violinplot([x,y])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x253ac46c1f0>,
#   <matplotlib.collections.PolyCollection at 0x253ac46c550>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x253ac46c160>,
#  'cmins': <matplotlib.collections.LineCollection at 0x253ac46cb80>,
#  'cbars': <matplotlib.collections.LineCollection at 0x253ac46cf10>}
